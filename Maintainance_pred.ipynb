# %% [markdown]
# ### Supervised Learning (Binary Classification)

# %% [markdown]
# #### Data Reading

# %%
import pandas as pd
import numpy as np
main = pd.read_csv(r"C:\ML_Lab\CTTC BBS\maintenance_data.csv")
main
# Out:
#      lifetime  broken  pressureInd  moistureInd  temperatureInd   team  \
# 0          56       0    92.178854   104.230204       96.517159  TeamA
# 1          81       1    72.075938   103.065701       87.271062  TeamC
# 2          60       0    96.272254    77.801376      112.196170  TeamA
# 3          86       1    94.406461   108.493608       72.025374  TeamC
# 4          34       0    97.752899    99.413492      103.756271  TeamB
# ..        ...     ...          ...          ...             ...    ...
# 995        88       1    88.589759   112.167556       99.861456  TeamB
# 996        88       1   116.727075   110.871332       95.075631  TeamA
# 997        22       0   104.026778    88.212873       83.221220  TeamB
# 998        78       0   104.911649   104.257296       83.421491  TeamA
# 999        63       0   116.901354    99.998694       47.641493  TeamB
#
#       provider
# 0    Provider4
# 1    Provider4
# 2    Provider1
# 3    Provider2
# 4    Provider1
# ..         ...
# ...

# %% [markdown]
# #### Data Analysis

# %%
main.head(3)
# Out:
#    lifetime  broken  pressureInd  moistureInd  temperatureInd   team  \
# 0        56       0    92.178854   104.230204       96.517159  TeamA
# 1        81       1    72.075938   103.065701       87.271062  TeamC
# 2        60       0    96.272254    77.801376      112.196170  TeamA
#
#     provider
# 0  Provider4
# 1  Provider4
# 2  Provider1

# %%
main.tail(3)
# Out:
#      lifetime  broken  pressureInd  moistureInd  temperatureInd   team  \
# 997        22       0   104.026778    88.212873       83.221220  TeamB
# 998        78       0   104.911649   104.257296       83.421491  TeamA
# 999        63       0   116.901354    99.998694       47.641493  TeamB
#
#       provider
# 997  Provider1
# 998  Provider4
# 999  Provider1

# %%
main.describe(include="all")
# Out:
#            lifetime       broken  pressureInd  moistureInd  temperatureInd  \
# count   1000.000000  1000.000000  1000.000000  1000.000000     1000.000000
# unique          NaN          NaN          NaN          NaN             NaN
# top             NaN          NaN          NaN          NaN             NaN
# freq            NaN          NaN          NaN          NaN             NaN
# mean      55.195000     0.397000    98.599338    99.376723      100.628541
# std       26.472737     0.489521    19.964052     9.988726       19.633060
# min        1.000000     0.000000    33.481917    58.547301       42.279598
# 25%       34.000000     0.000000    85.558076    92.771764       87.676913
# 50%       60.000000     0.000000    97.216997    99.433959      100.592277
# 75%       80.000000     1.000000   112.253190   106.120762      113.662885
# max       93.000000     1.000000   173.282541   128.595038      172.544140
#
#          team   provider
# count    1000       1000
# ...

# %%
main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   lifetime        1000 non-null   int64
#  1   broken          1000 non-null   int64
#  2   pressureInd     1000 non-null   float64
#  3   moistureInd     1000 non-null   float64
#  4   temperatureInd  1000 non-null   float64
#  5   team            1000 non-null   object
#  6   provider        1000 non-null   object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 54.8+ KB

# %% [markdown]
# #### Data Cleaning

# %%
main.isnull().sum()     # our data set have no null values
# Out:
# lifetime          0
# broken            0
# pressureInd       0
# moistureInd       0
# temperatureInd    0
# team              0
# provider          0
# dtype: int64

# %%
main.broken.unique().sum()
# Out:
# np.int64(1)

# %%
main.dtypes
# Out:
# lifetime            int64
# broken              int64
# pressureInd       float64
# moistureInd       float64
# temperatureInd    float64
# team               object
# provider           object
# dtype: object

# %%
# using for loop we check unique value in all columns
for i in main.columns:
    print(f"{i}:{main[i].unique()}\n")
# Out:
# lifetime:[56 81 60 86 34 30 68 65 23 38 29 82 80 48 92 88 74 61 35 26 63 79 53 73
#  13 36 31 25 58 19 84 12 15 43  1 20 16  3 18  7 47 39 57  4 24 28 49 76
#  52  8 40 46  5 41 93 77 62 85 55 33 17 45  9 72 50 42 44 54 64 27 22 59
#  66 83 14 51 71 21 78  6 69 89  2 67 87 11 10 32 37 90]
#
# broken:[0 1]
#
# pressureInd:[ 92.17885406  72.07593772  96.27225443  94.40646126  97.75289859
#   87.67880097  94.61417404  96.48330289 105.486158    99.17823531
#   97.81784409  67.81225145  86.36611059  76.14465414 103.1072633
#   88.41407945  84.35504868  79.66925455  86.22910861  84.17942039
#  100.0059233  115.6075596   97.69718903 101.4156229  118.9786971
#  102.1127749  129.1243378  109.0330362  107.2980695  127.2639544
#  138.1911205   72.55408417  95.21464918  91.24713174  81.55537698
#   69.13459519 132.8574784   54.73533145  84.89864628  94.15228726
#   84.34406647  95.75352436 123.9284399  101.5053508  120.9455502
#   83.06857115 113.3491219   75.64669299 113.4358321   81.77978353
# ...

# %%
for i in main.columns:
    print(f"{i}:{sum(main[i]=='?')}")
# Out:
# lifetime:0
# broken:0
# pressureInd:0
# moistureInd:0
# temperatureInd:0
# team:0
# provider:0

# %% [markdown]
# #### Data vizualization ( plotting )

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
sns.pairplot(main,hue='broken')
# mpg our output column

# %%
# violin plot`
for i in ['lifetime','pressureInd','moistureInd']:
    sns.violinplot(x=main.broken,y=main[i],hue=main.broken)
    plt.show()

# %% [markdown]
# ### Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
main.team=le.fit_transform(main.broken)
main.provider=le.fit_transform(main.broken)

# %%
ip = main.drop(['broken','team','provider'],axis=1)   # dropping cuz LinearRegression only accepts numerical values for the training.
ip.head(2)
# Out:
#    lifetime  pressureInd  moistureInd  temperatureInd
# 0        56    92.178854   104.230204       96.517159
# 1        81    72.075938   103.065701       87.271062

# %%
op = main.broken
op.head(2)
# Out:
# 0    0
# 1    1
# Name: broken, dtype: int64

# %% [markdown]
# ### train_test_split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(ip,op,test_size=0.2,random_state=42)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(x_test.shape)
# Out:
# (800, 4)
# (800,)
# (200, 4)
# (200, 4)

# %% [markdown]
# ### Model Training

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Predictions

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([-0.26333927, -0.00538291, -0.3047081 ,  0.42377727,  0.03614322,
#         0.42935416,  0.51367594,  0.52868769,  0.51410599, -0.31954123,
#         0.70700703,  0.64690586,  0.42811702,  0.42815864,  0.48833242,
#         0.40685144,  0.05652586,  0.48438271, -0.10309173, -0.28161342,
#         0.51952411,  0.53623269,  0.8202443 ,  0.11798659,  0.49682126,
#         0.48793761, -0.2547028 ,  0.82085999,  0.48093005,  0.8033206 ,
#         0.40802921,  0.52633746, -0.05142543,  0.71273961,  0.72697981,
#         0.60068163,  0.49128998,  0.78333546,  0.69634195, -0.04480182,
#         0.65818331,  0.51570729,  0.70961087,  0.49600408,  0.52403205,
#        -0.24186113, -0.1420551 ,  0.62656971,  0.56109862, -0.25270756,
#         0.52925454,  0.30882298,  0.783741  ,  0.72244514,  0.1407578 ,
#         0.42404391,  0.71594261,  0.15597619,  0.50364801,  0.12299179,
#        -0.01217948,  0.68629466, -0.27298432, -0.31315719,  0.70477256,
# ...
